# %% [markdown]
# 🧪 Exercícios de Dicionários e Tuplas em
# Python
# 🧠 Nível 1 – Fundamentos
# ✅ Exercício 1: Criando um dicionário com tupla
# Crie um dicionário chamado aluno com os seguintes dados:
# nome: "Lucas"
# idade: 17
# cursos: uma tupla com os cursos "Matemática" e "Python Básico"
# Depois, mostre os dados na tela, incluindo o segundo curso da tupla.

# %%
# Exercício 1
aluno = {
    "nome": "Lucas",
    "idade": 17,
    "cursos": ("Matemática", "Python Básico")
}

# Mostrando os dados
print("Nome do aluno:", aluno["nome"])
print("Idade do aluno:", aluno["idade"])
print("Segundo curso:", aluno["cursos"][1])  # Acessando o segundo curso

# %% [markdown]
# ✅ Exercício 2: Acessando dados da tupla
# Utilize o dicionário do exercício anterior para mostrar apenas:
# O nome do aluno
# O primeiro curso da tupla

# %%
# Exercício 2
print("Nome do aluno:", aluno["nome"])
print("Primeiro curso:", aluno["cursos"][0])  # Acessando o primeiro curso

# %% [markdown]
# ✅ Exercício 3: Alterando valores e adicionando chave com
# tupla
# No dicionário aluno , faça:
# Altere a idade para 18
# Adicione a chave "disciplinas_favoritas" com uma tupla: "Python" e "Algoritmos"
#
#
# Depois, exiba o dicionário completo.

# %%
# Exercício 3
aluno["idade"] = 18  # Alterando a idade
aluno["disciplinas_favoritas"] = ("Python", "Algoritmos")  # Adicionando nova chave

# Mostrando o dicionário atualizado
print(aluno)

# %% [markdown]
# ✅ Exercício 4: Usando .get() para acesso seguro
# Tente acessar a chave "nota_final" do dicionário usando o método .get() .
# Caso a chave não exista, exiba a mensagem "Nota ainda não cadastrada."
# 📌 Dica: .get("chave", "mensagem padrão") evita erros se a chave não existir.

# %%
# Exercício 4
nota_final = aluno.get("nota_final", "Nota ainda não cadastrada")
print(nota_final)  # Mostrando a mensagem padrão se a chave não existir

# %% [markdown]
# ✅ Exercício 5: Remover chave com del
# Remova a chave "disciplinas_favoritas" do dicionário.
# Depois, mostre o dicionário atualizado.

# %%
# Exercício 5
del aluno["disciplinas_favoritas"]  # Removendo a chave "disciplinas_favoritas"

# Mostrando o dicionário atualizado
print(aluno)

# %% [markdown]
# 🧩 Nível 2 – Trabalhando com listas e tuplas
# ✅ Exercício 6: Lista de compras com tupla
# Crie uma tupla de produtos com três itens.
# Depois, crie um dicionário compras onde:
# Cada produto da tupla é uma chave
# O valor é a quantidade comprada
# Percorra a tupla e mostre quantos itens de cada produto foram comprados.

# %%
# Exercício 6
produtos = ("Arroz", "Feijão", "Macarrão")
compras = {produto: 0 for produto in produtos}  # Inicializando o dicionário com valores 0

# Atualizando as quantidades
compras["Arroz"] = 5
compras["Feijão"] = 3
compras["Macarrão"] = 2

# Mostrando a quantidade comprada de cada produto
for produto, quantidade in compras.items():
    print(f"{produto}: {quantidade} unidades")

# %% [markdown]
# ✅ Exercício 7: Lista de alunos (com notas em tupla)
# Crie uma lista turma com 3 dicionários, um para cada aluno.
# Cada dicionário deve conter:
# nome
# idade
# notas : tupla com duas notas
# Percorra a lista e mostre o nome de cada aluno e sua média de notas.

# %%
# Exercício 7
turma = [
    {"nome": "João", "idade": 16, "notas": (7, 8)},
    {"nome": "Ana", "idade": 17, "notas": (9, 6)},
    {"nome": "Carlos", "idade": 18, "notas": (5, 5)}
]

# Calculando a média das notas de cada aluno
for aluno in turma:
    media = sum(aluno["notas"]) / len(aluno["notas"])
    print(f"{aluno['nome']} - Média das notas: {media}")

# %% [markdown]
# ✅ Exercício 8: Média geral da turma
# Usando os dados da lista turma , calcule a média geral das notas de todos os
# alunos juntos.

# %%
# Exercício 8
notas_turma = []
for aluno in turma:
    notas_turma.extend(aluno["notas"])  # Adicionando todas as notas à lista de notas da turma

# Calculando a média geral
media_geral = sum(notas_turma) / len(notas_turma)
print(f"Média geral da turma: {media_geral}")

# %% [markdown]
# ✅ Exercício 9: Maior nota da turma
# Percorra os alunos e descubra quem tirou a maior nota individual (de qualquer
# posição da tupla).
# Mostre o nome do aluno e o valor da nota.

# %%
# Exercício 9
maior_nota = 0
melhor_aluno = ""

for aluno in turma:
    nota_maxima = max(aluno["notas"])  # Pegando a maior nota do aluno
    if nota_maxima > maior_nota:
        maior_nota = nota_maxima
        melhor_aluno = aluno["nome"]

print(f"Melhor aluno: {melhor_aluno} com a nota {maior_nota}")

# %% [markdown]
# 🚀 Exercício 10: DESAFIO – Mini sistema de
# biblioteca com tuplas
# Crie um pequeno programa onde o usuário possa cadastrar livros, sendo que
# cada livro deve conter:
# título
# autor
# ano de publicação
# 📌 Cada livro será salvo como uma tupla: (título, autor, ano)
# Todos os livros devem ser guardados em uma lista chamada biblioteca .
# Ao final, exiba todos os livros cadastrados no formato:
#
# 📚 Livros cadastrados:
# 1. Título: Dom Casmurro | Autor: Machado de Assis | Ano: 1899
# 2. ...

# %%
# Exercício 10
biblioteca = []

# Loop para cadastrar livros
while True:
    titulo = input("Digite o título do livro: ")
    autor = input("Digite o autor do livro: ")
    ano = input("Digite o ano de publicação: ")

    livro = (titulo, autor, ano)  # Tupla representando o livro
    biblioteca.append(livro)  # Adicionando o livro à lista

    continuar = input("Deseja cadastrar outro livro? (sim/não): ")
    if continuar.lower() != "sim":
        break

# Exibindo os livros cadastrados
print("\n📚 Livros cadastrados:")
for i, livro in enumerate(biblioteca, start=1):
    print(f"{i}. Título: {livro[0]} | Autor: {livro[1]} | Ano: {livro[2]}")
