# %%
print ('Olá mundo')
print ("Olá Mundo")
print (1702)
print ('Marlos' , 'Gomes')
# Out:
# Olá mundo
# Olá Mundo
# 1702
# Marlos Gomes

# %%
nota1 = 10
nota2 = 9.5 / 1.5
nota3 = 9
media_geral = ((nota1+nota2+nota3)/3)
print (media_geral)
# Out:
# 8.444444444444445

# %%
faturamento = 150
custo = 60

# %%
lucro = faturamento-custo
print (lucro)
# Out:
# 90

# %%
input ('qual é o seu nome')
# Out:
# qual é o seu nomeMarlos
# 'Marlos'

# %%
input('Qual o seu nome ? ')
# Out:
# Qual o seu nome ? Marlos
# 'Marlos'

# %%
nome = input('Qual o seu nome?')
# Out:
# Qual o seu nome? marlos

# %%
print(nome) # Changed 'Print' to 'print'
# Out:
#  marlos

# %%
nome = input('Digite seu nome: ')
sobrenome = input('Digite seu sobrenome: ')
idade = input('Digite sua idade: ')
print(nome + sobrenome + idade)
# Out:
# Digite seu nome: Marlos
# Digite seu sobrenome: Gomes
# Digite sua idade: 22
# MarlosGomes22

# %%
nome = input('Digite seu nome: ')
sobrenome = input('Digite seu sobrenome: ')
idade = input('Digite sua idade: ')
print(f"Bem-Vindo, {nome} {sobrenome}! Você tem {idade} anos.")
# Out:
# Digite seu nome: Marlos
# Digite seu sobrenome: Gomes
# Digite sua idade: 22
# Bem-Vindo, Marlos Gomes! Você tem 22 anos.

# %%
nota1 = float(input('Digite a primeira Prova: '))
nota2 = float(input('Digite a segunda Prova: '))
nota3 = float(input('Digite a terceira Prova: '))
# Out:
# Digite a primeira Prova: 5
# Digite a segunda Prova: 10
# Digite a terceira Prova: 9

# %%
media = (nota1 + nota2 + nota3) / 3

# %%
print(f" A média das suas notas é: {media: .2f}")
# Out:
#  A média das suas notas é:  8.00

# %%
#EX003
dias = int(input('Digite a quantidade de dias: '))
# converte os dias para horas, minutos e segundos. #
horas = int(input('Digite a quantidade de horas: '))
minutos = int(input('Digite a quantidade de minutos: '))
segundos = int(input('Digite a quantidade de segundos: '))
# Out:
# Digite a quantidade de dias: 5
# Digite a quantidade de horas: 96
# Digite a quantidade de minutos: 1200
# Digite a quantidade de segundos: 100000

# %%
print(f"{dias} dias equivalem a: ")
print(f"{horas} horas equivalem a: ")
print(f"{minutos} minutos equivalem a: ")
print(f"{segundos} segundos equivalem a: ")
# Out:
# 5 dias equivalem a:
# 96 horas equivalem a:
# 1200 minutos equivalem a:
# 100000 segundos equivalem a:

# %%
#EX004
nome = input('Digite seu nome: ')
sobrenome = input('Digite seu sobrenome: ')
idade = int(input('Digite sua idade em anos: '))
# Out:
# Digite seu nome: Marlos
# Digite seu sobrenome: Gomes
# Digite sua idade em anos: 22

# %%
meses = idade * 12
semanas = idade * 52
dias = idade * 365
horas = dias * 24
minutos = horas * 60
segundos = minutos * 60

# %%
print("\nCadastro Completo: ")
print(f"nome: {nome} {sobrenome}")
print(f"idade: {idade} anos")
print(f"Equivalente a: ")
print(f"meses: {meses}")
print(f"semanas: {semanas}")
print(f"dias: {dias}")
print(f"horas: {horas}")
print(f"minutos: {minutos}")
print(f"segundos: {segundos}")
# Out:
# Cadastro Completo:
# nome: Marlos Gomes
# idade: 22 anos
# Equivalente a:
# meses: 264
# semanas: 1144
# dias: 8030
# horas: 192720
# minutos: 11563200
# segundos: 693792000

# %%
#*Exercício 5: Conversor de Moeda*#


valor_reais = float(input('Digite o valor em reais: '))
cotacao_dolar = float(input('Digite a cotação do dólar: '))

valor_dolar = valor_reais / cotacao_dolar

print(f'O valor em dólares é: {valor_dolar:.2f}')
# Out:
# Digite o valor em reais: 500
# Digite a cotação do dólar: 5.85
# O valor em dólares é: 85.47

# %%
# **Exercício 6: Cálculo do Tempo de Viagem**

distancia = float(input('Digite a distância da viagem (km): '))
velocidade = float(input('Digite a velocidade média (km/h): '))

tempo_horas = distancia / velocidade
tempo_minutos = (tempo_horas % 1) * 60

horas = int(tempo_horas)
minutos = int(round(tempo_minutos))

print(f'O tempo estimado de viagem é de aproximadamente {horas} horas e {minutos} minutos.')
# Out:
# Digite a distância da viagem (km): 988
# Digite a velocidade média (km/h): 120
# O tempo estimado de viagem é de aproximadamente 8 horas e 14 minutos.

# %%
# **Exercício 7: Cálculo de Área e Perímetro de um Retângulo**

largura = float(input('Digite a largura do retângulo (m): '))
altura = float(input('Digite a altura do retângulo (m): '))

area = largura * altura
perimetro = 2 * (largura + altura)

print(f'Área: {area} m²')
print(f'Perímetro: {perimetro} m')
# Out:
# Digite a largura do retângulo (m): 200
# Digite a altura do retângulo (m): 50
# Área: 10000.0 m²
# Perímetro: 500.0 m

# %%
# **Exercício 8: Cálculo do IMC**
peso = float(input('Digite seu peso (kg): '))
altura = float(input('Digite sua altura (m): '))

imc = peso / (altura ** 2)

if imc < 18.5:
  classificacao = 'Abaixo do Peso'
elif imc < 25:
  classificacao = 'Peso Normal'
elif imc < 30:
  classificacao = 'Sobrepeso'
elif imc < 35:
  classificacao = 'Obesidade Grau I'
elif imc < 40:
  classificacao = 'Obesidade Grau II'
else:
  classificacao = 'Obesidade Grau III'

print(f'Seu IMC é {imc:.2f} - Classificação: {classificacao}')
# Out:
# Digite seu peso (kg): 72
# Digite sua altura (m): 1.80
# Seu IMC é 22.22 - Classificação: Peso Normal

# %%
# **Exercício 9: Cálculo do Troco**
valor_compra = float(input('Digite o valor da compra: '))
valor_pago = float(input('Digite o valor pago pelo cliente: '))

troco = valor_pago - valor_compra

print(f'O troco a ser devolvido é R$ {troco:.2f}')
# Out:
# Digite o valor da compra: 50000
# Digite o valor pago pelo cliente: 55000
# O troco a ser devolvido é R$ 5000.00

# %%
# **Exercício 10: Conversor de Temperatura**
celsius = float(input('Digite a temperatura em Celsius: '))
fahrenheit = (celsius * 9/5) + 32
print(f'{celsius}°C equivalem a {fahrenheit}°F')
# Out:
# Digite a temperatura em Celsius: 32
# 32.0°C equivalem a 89.6°F
